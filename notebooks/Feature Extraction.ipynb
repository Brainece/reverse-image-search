# %%
from tensorflow import keras
import numpy as np
from numpy.linalg import norm
from tqdm import tqdm, tqdm_notebook
import os
import time
from keras.preprocessing import image
#import image
from keras.applications.resnet50 import ResNet50, preprocess_input
import pickle
import bz2 # compression tool
# Out:
# 2025-08-11 16:28:40.700217: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-11 16:28:40.926930: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-11 16:28:40.928434: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-11 16:28:42.068404: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
extensions = ['.jpg','.JPG','.jpeg','.JPEG','.png','.PNG']

# %%
model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

# %%
def extract_features(img_path, model): 
    """Function to extract the embeddings from the input image"""
    input_shape = (224,224,3)
    img = image.load_img(img_path, target_size=(input_shape[0],input_shape[1]))

    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array,axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    features = model.predict(preprocessed_img)

    flattened_features = features.flatten()
    normalized_features = flattened_features/norm(flattened_features)

    return normalized_features

# %%
def get_file_list(root_dir):
    file_list = []
    #counter = 1
    
    for root, directories, filenames in os.walk(root_dir):
        for filename in filenames:
            if any(ext in filename for ext in extensions):
                file_path = os.path.join(root,filename)
                if os.path.exists(file_path):
                    file_list.append(file_path)
                else:
                    print(file_path)
    
    return file_list

# %%
root_dir = "./caltech101/"
filenames = sorted(get_file_list(root_dir))
print(len(filenames))
# Out:
# 8677

# %%
# extract features from the files
feature_list = []
for i in tqdm_notebook(range(len(filenames))):
    feature_list.append(extract_features(filenames[i],model))
# Out:
# /tmp/ipykernel_1704296/3521412417.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(filenames))):
#   0%|          | 0/8677 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# ...

# %%
#pickle.dump(feature_list,open('features.pickle', 'wb'))
#ofile = bz2.BZ2File("BinaryData",'wb')
with bz2.BZ2File('features.pickle', 'wb') as f:
    pickle.dump(feature_list, f)
#print("size of feature_list: " + str(feature_list.__sizeof__()) + " bytes

# %%
pickle.dump(filenames,open('filenames.pickle','wb'))

# %%
# perform PCA over the features
num_features_dimensions = 100
pca = PCA
